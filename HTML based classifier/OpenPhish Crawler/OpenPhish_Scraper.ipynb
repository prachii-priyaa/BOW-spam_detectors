# %%
import requests
import csv
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page containing phishing URLs
url = "https://openphish.com/"

# Send a GET request to the URL
response = requests.get(url)

# Create a BeautifulSoup object from the response content
soup = BeautifulSoup(response.content, "html.parser")

print(soup.prettify)
# Out:
# <bound method Tag.prettify of <html lang="en">
# <head>
# <meta content="OpenPhish provides actionable intelligence data on active phishing threats." name="description"/>
# <meta content="300" http-equiv="refresh"/>
# <title>OpenPhish - Phishing Intelligence</title>
# <link href="https://fonts.googleapis.com/css?family=Open+Sans:400,600&amp;subset=latin" rel="stylesheet" type="text/css"/>
# <link href="static/table-min.css" rel="stylesheet" type="text/css"/>
# <link href="static/bootstrap.css" rel="stylesheet" type="text/css"/>
# <link href="static/site.css" rel="stylesheet" type="text/css"/>
# <style>
# .table td, .table th {
#     overflow: hidden;
#     text-overflow: ellipsis;
#     white-space: nowrap;
#     font-size: 14px;
# }
# .url_entry {
# 	color: #337ab7;
# }
# </style>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.11.3/jquery.min.js"></script>
# <script crossorigin="anonymous" integrity="sha384-0mSbJDEHialfmuBBQP6A4Qrprq5OVfW37PRR3j5ELqxss1yVqOtnepnHVP9aJ7xS" src="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.6/js/bootstrap.min.js"></script>
# </head>
# <body>
# <div id="wrap" style="padding-top: 20px;">
# <nav class="navbar navbar-default navbar-fixed-top">
# <div class="container">
# <ol class="breadcrumb">
# <li style="margin-right:-150px">
# <a alt="OpenPhish Homepage" href="index.html">
# <span><img alt="OpenPhish Logo" class="logo" src="static/openphish_logo2.png"/></span>
# </a>
# </li>
# <li>
# <a alt="OpenPhish Phishing Feed" href="phishing_feeds.html">Phishing Feeds</a>
# </li>
# <li>
# <a alt="OpenPhish Phishing Database" href="phishing_database.html">Phishing Database</a>
# </li>
# <li class="nav-item dropdown">
# <a class="nav-link dropdown-toggle" data-toggle="dropdown" href="#">Resources</a>
# <ul class="dropdown-menu">
# <li>
# <a alt="OpenPhish Phishing Database API" class="dropdown-item" href="https://github.com/openphish/pyopdb" target="_blank">OpenPhish API</a>
# </li>
# <li>
# <a alt="OpenPhish News &amp; Updates" class="dropdown-item" href="whatsnew.html">Recent Updates</a>
# </li>
# <li>
# <a alt="OpenPhish Global Phishing Activity Map" class="dropdown-item" href="phishing_activity.html">Global Phishing Activity</a>
# </li>
# </ul>
# </li>
# </ol>
# </div>
# </nav>
# <div class="container">
# <div class="page-header">
# <center><h2 style="font-size: 20px;">Timely. Accurate. Relevant Phishing Intelligence.</h2></center>
# <div style="padding-top:10px;text-align:center"><p><span class="glyphicon glyphicon-stats"> </span> 7-Day Phishing Trends</p></div>
# <div class="homepage_counter_1" style="width: 33%; margin-top: 10px">
# <span style="font-size:24px;">10,392,540</span>
# <p>URLs Processed</p>
# </div>
# <div class="homepage_counter_1" style="width: 33%; margin-top: 10px">
# <span style="font-size:24px;">25,391</span>
# <p>Phishing Campaigns</p>
# </div>
# <div class="homepage_counter_2" style="width: 33%; margin-top: 10px">
# <span style="font-size:24px;">267</span>
# <p>Brands Targeted</p>
# </div>
# </div>
# <table class="pure-table pure-table-striped" style="background-color: #white">
# <thead>
# <tr>
# <th style="width:61%">Phishing URL</th>
# <th style="width:29%">Targeted Brand</th>
# <th style="width:10%">Time</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td class="url_entry">https://www.animagricola.farm/ssl/animagricola/Banks-ec/amJhbmtzQGJhbmtzLWVjLmNvbQ==</td>
# <td>Generic/Spear Phishing</td>
# <td>15:41:03</td>
# </tr>
# <tr>
# <td class="url_entry">https://fcv2.xyz/?s=RDETMGxC</td>
# <td>WhatsApp</td>
# <td>15:32:44</td>
# </tr>
# <tr>
# <td class="url_entry">https://www.securembly.org/nam/1ab41d5a-8833-4af0-82be-e3c54d03997b/55914fdf-43ac-4604-b5a8-cb5be99f0a32/5e4a3c92-2b06-45fa-9b7a-4d20d50df3b6/login?id=...</td>
# <td>Office365</td>
# <td>15:32:06</td>
# </tr>
# <tr>
# <td class="url_entry">https://elleganto.com.br/</td>
# <td>Mercado Libre</td>
# <td>15:31:06</td>
# </tr>
# <tr>
# <td class="url_entry">http://pub-955b4ab970884f6ebc951948e5966969.r2.dev/secondpage.html</td>
# <td>Outlook</td>
# <td>15:30:48</td>
# </tr>
# <tr>
# <td class="url_entry">http://24.75.29.68/enrollment</td>
# <td>M &amp; T Bank Coporation</td>
# <td>15:29:59</td>
# </tr>
# <tr>
# <td class="url_entry">https://ipfs.io/ipfs/QmQqgUohatR5fDg25dYJc2eaXpoe9pq8YhQ8M9o7gtypRj?filename=dhl.html&amp;data=YmFsQG1vcmFuc2hpcHBpbmcuY29t&amp;subf=Transport-Label.pdf&amp;file=Waybill.pdf</td>
# <td>DHL Airways, Inc.</td>
# <td>15:24:27</td>
# </tr>
# <tr>
# <td class="url_entry">https://jade-hulking-trumpet.glitch.me/public/ntw.html?/NATWESTB.ANKCRE.CARD/info.htm</td>
# <td>NatWest Personal Banking</td>
# <td>15:23:21</td>
# </tr>
# <tr>
# <td class="url_entry">https://ipfs.io/ipfs/QmcQch1P6Po7peexKx7UDp7TazThKCu2pAsdnU9WSaUVta</td>
# <td>Microsoft OneDrive</td>
# <td>15:21:49</td>
# </tr>
# <tr>
# <td class="url_entry">https://metamaskwalletrestore.office-on-the.net/u/fh/f38ac7b8aff6fd620b227cb60d7a85ca</td>
# <td>Crypto/Wallet</td>
# <td>15:17:41</td>
# </tr>
# <tr>
# <td class="url_entry">https://bugoutdepot.us/kinhjgu/NewATT/New%20ATT/Auto%20Pay.html</td>
# <td>AT&amp;T Inc.</td>
# <td>15:14:41</td>
# </tr>
# <tr>
# <td class="url_entry">http://biswadip200.github.io/Netflix-Clone.github.io</td>
# <td>Netflix Inc.</td>
# <td>15:14:16</td>
# </tr>
# <tr>
# <td class="url_entry">https://sociallycollect.com/odocapenter</td>
# <td>La Banque postale</td>
# <td>15:12:24</td>
# </tr>
# <tr>
# <td class="url_entry">https://ipfs.eth.aragon.network/ipfs/bafkreihcipk64vg3r272mfbs4aciyxupe4kzs5cs6tkt6ituepy7ybhkki</td>
# <td>1&amp;1 Ionos</td>
# <td>15:12:24</td>
# </tr>
# <tr>
# <td class="url_entry">http://www.total-escort.com/exc/new%20excel/</td>
# <td>Adobe Inc.</td>
# <td>15:00:25</td>
# </tr>
# <tr>
# <td class="url_entry">http://sahabat-malam.cloud/</td>
# <td>Telegram</td>
# <td>14:59:38</td>
# </tr>
# <tr>
# <td class="url_entry">http://layananbantuan.dana-id-web.my.id/main.php</td>
# <td>DANA</td>
# <td>14:58:54</td>
# </tr>
# <tr>
# <td class="url_entry">http://tokyo.paypay-lnsurance.com/index/index/loginz.html</td>
# <td>PayPay</td>
# <td>14:58:51</td>
# </tr>
# <tr>
# <td class="url_entry">http://countdown.themarketingblerd.com/</td>
# <td>Webmail Providers</td>
# <td>14:50:37</td>
# </tr>
# <tr>
# <td class="url_entry">http://aejk0.webintwo.bid/?uid=vwxcjxpf</td>
# <td>PayPal Inc.</td>
# <td>14:46:19</td>
# </tr>
# <tr>
# <td class="url_entry">https://logieproduction.info/</td>
# <td>Idaho Central Credit Union</td>
# <td>14:46:00</td>
# </tr>
# <tr>
# <td class="url_entry">https://my-site-105101-109662.weeblysite.com/</td>
# <td>BT Group plc</td>
# <td>14:42:27</td>
# </tr>
# <tr>
# <td class="url_entry">http://ogloszenie-samochody.pl/</td>
# <td>Facebook, Inc.</td>
# <td>14:39:09</td>
# </tr>
# <tr>
# <td class="url_entry">http://griffithdds.com/.well-known/madeinchina.com/logon.do.php</td>
# <td>Made-In-China</td>
# <td>14:34:52</td>
# </tr>
# <tr>
# <td class="url_entry">http://cosmosgrp.com/fr/authentification/se-connecter/connexion/login/9A7886128401298409798768124H7/credit-agricole</td>
# <td>Credit Agricole S.A.</td>
# <td>14:24:43</td>
# </tr>
# <tr>
# <td class="url_entry">https://dota2workshop.com/</td>
# <td>Steam</td>
# <td>14:20:16</td>
# </tr>
# <tr>
# <td class="url_entry">http://291795384.com/</td>
# <td>Bank of China</td>
# <td>14:12:28</td>
# </tr>
# <tr>
# <td class="url_entry">http://apple.com-system-1948590.xyz/</td>
# <td>Apple Inc.</td>
# <td>14:12:22</td>
# </tr>
# <tr>
# <td class="url_entry">https://taxinfoproccess.com/?serah</td>
# <td>IRS</td>
# <td>14:05:09</td>
# </tr>
# <tr>
# <td class="url_entry">https://neydukip.square.site/</td>
# <td>AT&amp;T</td>
# <td>14:04:09</td>
# </tr>
# </tbody>
# </table>
# <div style="text-align: center; padding-top: 10px;">
# <strong><a href="feed.txt" rel="nofollow">Download Free Phishing Feed</a></strong>
# <p style="font-size:11px; line-height:20px;margin:auto;width: 49%">
#   By using the Free Phishing Feed, you agree to our <a href="terms.html">Terms of Use</a>.
#   </p>
# </div>
# </div>
# <footer class="footer">
# <div class="container" style="text-align: center;">
# <p class="text-muted">
# 	© OpenPhish |
# 	<a href="kb.html">Knowledge Base</a> |
# 	<a href="terms.html">Terms of Use</a> |
# 	<a href="mailto:report@openphish.com">Report Phishing</a> |
# 	<a href="mailto:contact@openphish.com">Contact Us</a>
# </p>
# </div>
# </footer>
# </div>
# </body>
# </html>
# >

# %%
# Find all URL entries with the class 'url_entry'
url_entries = soup.find_all(class_='url_entry')

# Extract the URLs
phishing_urls = [entry.text for entry in url_entries]

# Specify the CSV file path
csv_file = 'phishing_urls.csv'

# Save the URLs to the CSV file
with open(csv_file, 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Phishing URL'])
    writer.writerows([[url] for url in phishing_urls])

print(f"Phishing URLs saved to {csv_file}.")
# Out:
# Phishing URLs saved to phishing_urls.csv.

# %%
df = pd.read_csv('phishing_urls.csv')

# %%
df.head
# Out:
# <bound method NDFrame.head of                                          Phishing URL
# 0   https://www.animagricola.farm/ssl/animagricola...
# 1                        https://fcv2.xyz/?s=RDETMGxC
# 2   https://www.securembly.org/nam/1ab41d5a-8833-4...
# 3                           https://elleganto.com.br/
# 4   http://pub-955b4ab970884f6ebc951948e5966969.r2...
# 5                       http://24.75.29.68/enrollment
# 6   https://ipfs.io/ipfs/QmQqgUohatR5fDg25dYJc2eaX...
# 7   https://jade-hulking-trumpet.glitch.me/public/...
# 8   https://ipfs.io/ipfs/QmcQch1P6Po7peexKx7UDp7Ta...
# 9   https://metamaskwalletrestore.office-on-the.ne...
# 10  https://bugoutdepot.us/kinhjgu/NewATT/New%20AT...
# 11  http://biswadip200.github.io/Netflix-Clone.git...
# 12            https://sociallycollect.com/odocapenter
# 13  https://ipfs.eth.aragon.network/ipfs/bafkreihc...
# 14       http://www.total-escort.com/exc/new%20excel/
# 15                        http://sahabat-malam.cloud/
# 16   http://layananbantuan.dana-id-web.my.id/main.php
# 17  http://tokyo.paypay-lnsurance.com/index/index/...
# 18            http://countdown.themarketingblerd.com/
# 19            http://aejk0.webintwo.bid/?uid=vwxcjxpf
# 20                      https://logieproduction.info/
# 21      https://my-site-105101-109662.weeblysite.com/
# 22                    http://ogloszenie-samochody.pl/
# 23  http://griffithdds.com/.well-known/madeinchina...
# 24  http://cosmosgrp.com/fr/authentification/se-co...
# 25                         https://dota2workshop.com/
# 26                              http://291795384.com/
# 27               http://apple.com-system-1948590.xyz/
# 28                 https://taxinfoproccess.com/?serah
# 29                      https://neydukip.square.site/>

# %% [markdown]
# **TXT FILES**

# %%
import os
import sys

# Increase the field size limit
csv.field_size_limit(sys.maxsize)

urls = df['Phishing URL']

# Function to extract HTML content from a URL
def extract_html(url):
    try:
        response = requests.get(url, timeout=10)  # Add timeout parameter (adjust as needed)
        return response.text
    except requests.exceptions.RequestException as e:
        print(f"Error occurred while accessing {url}: {e}")
        return None

# Create a directory to store individual TXT files
txt_directory = 'txt_files'
os.makedirs(txt_directory, exist_ok=True)

# Iterate over the URLs and extract HTML content
for i, url in enumerate(urls):
    html = extract_html(url)

    if html is not None:
        # Specify the TXT file path
        txt_file = os.path.join(txt_directory, f'html_{i}.txt')

        # Save the HTML content as TXT
        with open(txt_file, 'w', encoding='utf-8') as file:
            file.write(html)

        print(f"HTML content of {url} saved as TXT: {txt_file}.")
    else:
        print(f"Skipping URL {url} due to an error.")

print("HTML content saved as TXT files in txt_files folder.")
# Out:
# HTML content of https://www.animagricola.farm/ssl/animagricola/Banks-ec/amJhbmtzQGJhbmtzLWVjLmNvbQ== saved as TXT: txt_files/html_0.txt.
# HTML content of https://fcv2.xyz/?s=RDETMGxC saved as TXT: txt_files/html_1.txt.
# HTML content of https://www.securembly.org/nam/1ab41d5a-8833-4af0-82be-e3c54d03997b/55914fdf-43ac-4604-b5a8-cb5be99f0a32/5e4a3c92-2b06-45fa-9b7a-4d20d50df3b6/login?id=... saved as TXT: txt_files/html_2.txt.
# HTML content of https://elleganto.com.br/ saved as TXT: txt_files/html_3.txt.
# WARNING:urllib3.connection:Certificate did not match expected hostname: 24.75.29.68. Certificate: {'subject': ((('countryName', 'US'),), (('stateOrProvinceName', 'New York'),), (('localityName', 'Buffalo'),), (('jurisdictionCountryName', 'US'),), (('jurisdictionStateOrProvinceName', 'New York'),), (('organizationName', 'M&T Bank Corporation'),), (('businessCategory', 'Private Organization'),), (('serialNumber', '284484'),), (('commonName', 'nao.mtb.com'),)), 'issuer': ((('countryName', 'US'),), (('organizationName', 'Entrust, Inc.'),), (('organizationalUnitName', 'See www.entrust.net/legal-terms'),), (('organizationalUnitName', '(c) 2014 Entrust, Inc. - for authorized use only'),), (('commonName', 'Entrust Certification Authority - L1M'),)), 'version': 3, 'serialNumber': '6FEAC66D3E14E0EB9D775B8C0F576D4E', 'notBefore': 'Aug  8 14:37:05 2022 GMT', 'notAfter': 'Sep  2 14:37:05 2023 GMT', 'subjectAltName': (('DNS', 'nao.mtb.com'), ('DNS', 'auth.mtb.com'), ('DNS', 'm.mtb.com'), ('DNS', 'pcl-auth.mtb.com'), ('DNS', 'mls-auth.mtb.com')), 'OCSP': ('http://ocsp.entrust.net',), 'caIssuers': ('http://aia.entrust.net/l1m-chain256.cer',), 'crlDistributionPoints': ('http://crl.entrust.net/level1m.crl',)}
# HTML content of http://pub-955b4ab970884f6ebc951948e5966969.r2.dev/secondpage.html saved as TXT: txt_files/html_4.txt.
# Error occurred while accessing http://24.75.29.68/enrollment: HTTPSConnectionPool(host='24.75.29.68', port=443): Max retries exceeded with url: /enrollment (Caused by SSLError(CertificateError("hostname '24.75.29.68' doesn't match either of 'nao.mtb.com', 'auth.mtb.com', 'm.mtb.com', 'pcl-auth.mtb.com', 'mls-auth.mtb.com'")))
# Skipping URL http://24.75.29.68/enrollment due to an error.
# HTML content of https://ipfs.io/ipfs/QmQqgUohatR5fDg25dYJc2eaXpoe9pq8YhQ8M9o7gtypRj?filename=dhl.html&data=YmFsQG1vcmFuc2hpcHBpbmcuY29t&subf=Transport-Label.pdf&file=Waybill.pdf saved as TXT: txt_files/html_6.txt.
# HTML content of https://jade-hulking-trumpet.glitch.me/public/ntw.html?/NATWESTB.ANKCRE.CARD/info.htm saved as TXT: txt_files/html_7.txt.
# HTML content of https://ipfs.io/ipfs/QmcQch1P6Po7peexKx7UDp7TazThKCu2pAsdnU9WSaUVta saved as TXT: txt_files/html_8.txt.
# HTML content of https://metamaskwalletrestore.office-on-the.net/u/fh/f38ac7b8aff6fd620b227cb60d7a85ca saved as TXT: txt_files/html_9.txt.
# HTML content of https://bugoutdepot.us/kinhjgu/NewATT/New%20ATT/Auto%20Pay.html saved as TXT: txt_files/html_10.txt.
# HTML content of http://biswadip200.github.io/Netflix-Clone.github.io saved as TXT: txt_files/html_11.txt.
# HTML content of https://sociallycollect.com/odocapenter saved as TXT: txt_files/html_12.txt.
# HTML content of https://ipfs.eth.aragon.network/ipfs/bafkreihcipk64vg3r272mfbs4aciyxupe4kzs5cs6tkt6ituepy7ybhkki saved as TXT: txt_files/html_13.txt.
# HTML content of http://www.total-escort.com/exc/new%20excel/ saved as TXT: txt_files/html_14.txt.
# HTML content of http://sahabat-malam.cloud/ saved as TXT: txt_files/html_15.txt.
# HTML content of http://layananbantuan.dana-id-web.my.id/main.php saved as TXT: txt_files/html_16.txt.
# Error occurred while accessing http://tokyo.paypay-lnsurance.com/index/index/loginz.html: HTTPConnectionPool(host='tokyo.paypay-lnsurance.com', port=80): Read timed out. (read timeout=10)
# Skipping URL http://tokyo.paypay-lnsurance.com/index/index/loginz.html due to an error.
# HTML content of http://countdown.themarketingblerd.com/ saved as TXT: txt_files/html_18.txt.
# HTML content of http://aejk0.webintwo.bid/?uid=vwxcjxpf saved as TXT: txt_files/html_19.txt.
# HTML content of https://logieproduction.info/ saved as TXT: txt_files/html_20.txt.
# HTML content of https://my-site-105101-109662.weeblysite.com/ saved as TXT: txt_files/html_21.txt.
# HTML content of http://ogloszenie-samochody.pl/ saved as TXT: txt_files/html_22.txt.
# HTML content of http://griffithdds.com/.well-known/madeinchina.com/logon.do.php saved as TXT: txt_files/html_23.txt.
# HTML content of http://cosmosgrp.com/fr/authentification/se-connecter/connexion/login/9A7886128401298409798768124H7/credit-agricole saved as TXT: txt_files/html_24.txt.
# HTML content of https://dota2workshop.com/ saved as TXT: txt_files/html_25.txt.
# Error occurred while accessing http://291795384.com/: HTTPConnectionPool(host='291795384.com', port=80): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7ad448d36950>, 'Connection to 291795384.com timed out. (connect timeout=10)'))
# Skipping URL http://291795384.com/ due to an error.
# Error occurred while accessing http://apple.com-system-1948590.xyz/: HTTPConnectionPool(host='apple.com-system-1948590.xyz', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7ad448d37610>: Failed to establish a new connection: [Errno -2] Name or service not known'))
# Skipping URL http://apple.com-system-1948590.xyz/ due to an error.
# Error occurred while accessing https://taxinfoproccess.com/?serah: HTTPSConnectionPool(host='taxinfoproccess.com', port=443): Max retries exceeded with url: /?serah (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7ad448d37250>: Failed to establish a new connection: [Errno -2] Name or service not known'))
# Skipping URL https://taxinfoproccess.com/?serah due to an error.
# HTML content of https://neydukip.square.site/ saved as TXT: txt_files/html_29.txt.
# HTML content saved as TXT files in txt_files folder.

# %%
import shutil
import os

# Specify the path of the "txt_files" folder in Colab
colab_folder_path = 'txt_files'

# Specify the destination path and filename for the ZIP file on your local machine
local_zip_path = '/content/txt_files.zip'

# Create a ZIP file containing the "txt_files" folder
shutil.make_archive('/content/txt_files', 'zip', colab_folder_path)

# Move the ZIP file to the desired location
shutil.move('/content/txt_files.zip', local_zip_path)

print("ZIP file created successfully.")

# Provide the download link for the ZIP file
print("Download the ZIP file from the following link:")
print(local_zip_path)
# Out:
# ZIP file created successfully.
# Download the ZIP file from the following link:
# /content/txt_files.zip
